# %% [markdown]
# <a href="https://colab.research.google.com/github/NisanthanG/Image-Scaling-Using-Computer-Vision-Assignment-01-/blob/main/Untitled12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt
from google.colab import files

# %%
# Upload image file for transformation
image_1 = files.upload()
# Out:
#      <input type="file" id="files-022b6887-12ac-4a62-9db9-2bafe9afca78" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-022b6887-12ac-4a62-9db9-2bafe9afca78">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
image_path = list(image_1.keys())[0]

# Read image (BGR → RGB)
img = cv.imread(image_path)
img = cv.cvtColor(img, cv.COLOR_BGR2RGB)

# Normalize image to [0,1]
img_norm = img / 255.0

# %%
#0.5 gamma correction
img_gamma_half = np.power(img_norm, 0.5)

# 2 gamma correction
img_gamma_two = np.power(img_norm, 2)

# %%
# show image results
plt.figure(figsize=(10, 10))
plt.subplot(1, 3, 1)
plt.imshow(img)
plt.title('Original image')
plt.axis('off')
plt.subplot(1, 3, 2)
plt.imshow(img_gamma_half)
plt.title('0.5 gamma correction')
plt.axis('off')
plt.subplot(1, 3, 3)
plt.imshow(img_gamma_two)
plt.title('2 gamma correction')
plt.axis('off')
plt.show()

# %%
#  img_norm has the normalized image to [0,1]
#  Contrast Stretching (linear piecewise transformation)
stretched_img = np.zeros_like(img_norm)
r1 = 0.2
r2 = 0.8
# apply r1 = 0.2
stretched_img[img_norm < r1] = 0
mask = (img_norm >= r1) & (img_norm < r2)
stretched_img[mask] = (img_norm[mask] - r1) / (r2 - r1)
stretched_img[img_norm >= r2] = 1

#show results
plt.figure(figsize=(10, 10))
plt.subplot(1,2,1)
plt.imshow(img)
plt.title('Original image')
plt.axis('off')
plt.subplot(1,2,2)
plt.imshow(stretched_img)
plt.title('Contrast Stretching')
plt.axis('off')
plt.show()
